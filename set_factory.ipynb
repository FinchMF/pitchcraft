# %%
from itertools import combinations

# %%
all_four_voice = combinations(list(range(0,12)), 4)

# %%
for chord in all_four_voice:
    print(chord)
# Out:
# (0, 1, 2, 3)
# (0, 1, 2, 4)
# (0, 1, 2, 5)
# (0, 1, 2, 6)
# (0, 1, 2, 7)
# (0, 1, 2, 8)
# (0, 1, 2, 9)
# (0, 1, 2, 10)
# (0, 1, 2, 11)
# (0, 1, 3, 4)
# (0, 1, 3, 5)
# (0, 1, 3, 6)
# (0, 1, 3, 7)
# (0, 1, 3, 8)
# (0, 1, 3, 9)
# (0, 1, 3, 10)
# (0, 1, 3, 11)
# (0, 1, 4, 5)
# (0, 1, 4, 6)
# (0, 1, 4, 7)
# (0, 1, 4, 8)
# (0, 1, 4, 9)
# (0, 1, 4, 10)
# (0, 1, 4, 11)
# (0, 1, 5, 6)
# (0, 1, 5, 7)
# (0, 1, 5, 8)
# (0, 1, 5, 9)
# (0, 1, 5, 10)
# (0, 1, 5, 11)
# (0, 1, 6, 7)
# (0, 1, 6, 8)
# (0, 1, 6, 9)
# (0, 1, 6, 10)
# (0, 1, 6, 11)
# (0, 1, 7, 8)
# (0, 1, 7, 9)
# (0, 1, 7, 10)
# (0, 1, 7, 11)
# (0, 1, 8, 9)
# (0, 1, 8, 10)
# (0, 1, 8, 11)
# (0, 1, 9, 10)
# (0, 1, 9, 11)
# (0, 1, 10, 11)
# (0, 2, 3, 4)
# (0, 2, 3, 5)
# (0, 2, 3, 6)
# (0, 2, 3, 7)
# (0, 2, 3, 8)
# (0, 2, 3, 9)
# (0, 2, 3, 10)
# (0, 2, 3, 11)
# (0, 2, 4, 5)
# (0, 2, 4, 6)
# (0, 2, 4, 7)
# (0, 2, 4, 8)
# (0, 2, 4, 9)
# (0, 2, 4, 10)
# (0, 2, 4, 11)
# (0, 2, 5, 6)
# (0, 2, 5, 7)
# (0, 2, 5, 8)
# (0, 2, 5, 9)
# (0, 2, 5, 10)
# ...
