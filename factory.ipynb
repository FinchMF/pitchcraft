# %%
import util
import generator

# %%
generator.Hz().update('base_tone')

# %%
PITCH = generator.Hz(util.pitch_to_hz['A'][4])

# %%
PITCH.hz
# Out:
# 440.0

# %%
PITCH.intervals
# Out:
# {'0-0': 1.122462048309373,
#  '0-1': 1.2599210498948732,
#  '0-2': 1.414213562373095,
#  '0-3': 1.5874010519681994,
#  '0-4': 1.7817974362806785,
#  '0-5': 2.0}

# %%
PITCH.system_size
# Out:
# 40

# %%
PITCH.make_system()
# Out:
# {'freq_0': 440.0,
#  'freq_1': 493.88,
#  'freq_2': 554.37,
#  'freq_3': 622.25,
#  'freq_4': 698.46,
#  'freq_5': 783.99,
#  'freq_6': 880.0,
#  'freq_7': 987.77,
#  'freq_8': 1108.73,
#  'freq_9': 1244.51,
#  'freq_10': 1396.91,
#  'freq_11': 1567.98,
#  'freq_12': 1760.0,
#  'freq_13': 1975.53,
#  'freq_14': 2217.46,
#  'freq_15': 2489.02,
#  'freq_16': 2793.83,
#  'freq_17': 3135.96,
#  'freq_18': 3520.0,
#  'freq_19': 3951.07,
#  'freq_20': 4434.92,
#  'freq_21': 4978.03,
#  'freq_22': 5587.65,
#  'freq_23': 6271.93,
#  'freq_24': 7040.0,
#  'freq_25': 7902.13,
#  'freq_26': 8869.84,
#  'freq_27': 9956.06,
#  'freq_28': 11175.3,
#  'freq_29': 12543.85,
#  'freq_30': 14080.0,
#  'freq_31': 15804.27,
#  'freq_32': 17739.69,
#  'freq_33': 19912.13,
#  'freq_34': 22350.61,
#  'freq_35': 25087.71,
#  'freq_36': 28160.0,
#  'freq_37': 31608.53,
#  'freq_38': 35479.38,
#  'freq_39': 39824.25}

# %%
PITCH.make_overtone_series()
# Out:
# [0.0,
#  440.0,
#  880.0,
#  1320.0,
#  1760.0,
#  2200.0,
#  2640.0,
#  3080.0,
#  3520.0,
#  3960.0,
#  4400.0,
#  4840.0,
#  5280.0,
#  5720.0,
#  6160.0,
#  6600.0]

# %%
generator.Wav(carrier_hz=PITCH.hz).make_wav('sawtooth')

# %%
wav_data = generator.Wav(carrier_hz=PITCH.hz).sawtooth_carrier

# %%
# !ls
# Out:
# README.md                 factory.ipynb             simple_440.0_sawtooth.wav
# __pycache__               generator.py              util.py
# app.py                    sample_packages

# %%
import librosa
import librosa.display
import numpy as np 
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.rcParams['axes.facecolor'] = 'black'
plt.plot(wav_data[:500], color='red')

# %%
y, sr = librosa.load('simple_440.0_sawtooth.wav')

# %%
fig, ax = plt.subplots(figsize=(15,15))
img = librosa.display.specshow(S_db, x_axis='time', y_axis='linear', ax=ax)
