# %%
import util
import generator

# %%
generator.Hz().update('base_tone')

# %%
PITCH = generator.Hz(util.Transform.pitch_to_hz['A'][4])

# %%
PITCH.hz
# Out:
# 440.0

# %%
PITCH.interval_system_base_unit
# Out:
# 1.0594630943592953

# %%
PITCH.hz * PITCH.intervals['0-1']
# Out:
# 493.8833012561241

# %%
PITCH.system_size
# Out:
# 88

# %%
PITCH.make_system()
# Out:
# {'freq_0': 440.0,
#  'freq_1': 466.16,
#  'freq_2': 493.88,
#  'freq_3': 523.25,
#  'freq_4': 554.37,
#  'freq_5': 587.33,
#  'freq_6': 622.25,
#  'freq_7': 659.26,
#  'freq_8': 698.46,
#  'freq_9': 739.99,
#  'freq_10': 783.99,
#  'freq_11': 830.61,
#  'freq_12': 880.0,
#  'freq_13': 932.33,
#  'freq_14': 987.77,
#  'freq_15': 1046.5,
#  'freq_16': 1108.73,
#  'freq_17': 1174.66,
#  'freq_18': 1244.51,
#  'freq_19': 1318.51,
#  'freq_20': 1396.91,
#  'freq_21': 1479.98,
#  'freq_22': 1567.98,
#  'freq_23': 1661.22,
#  'freq_24': 1760.0,
#  'freq_25': 1864.66,
#  'freq_26': 1975.53,
#  'freq_27': 2093.0,
#  'freq_28': 2217.46,
#  'freq_29': 2349.32,
#  'freq_30': 2489.02,
#  'freq_31': 2637.02,
#  'freq_32': 2793.83,
#  'freq_33': 2959.96,
#  'freq_34': 3135.96,
#  'freq_35': 3322.44,
#  'freq_36': 3520.0,
#  'freq_37': 3729.31,
#  'freq_38': 3951.07,
#  'freq_39': 4186.01,
#  'freq_40': 4434.92,
#  'freq_41': 4698.64,
#  'freq_42': 4978.03,
#  'freq_43': 5274.04,
#  'freq_44': 5587.65,
#  'freq_45': 5919.91,
#  'freq_46': 6271.93,
#  'freq_47': 6644.88,
#  'freq_48': 7040.0,
#  'freq_49': 7458.62,
#  'freq_50': 7902.13,
#  'freq_51': 8372.02,
#  'freq_52': 8869.84,
#  'freq_53': 9397.27,
#  'freq_54': 9956.06,
#  'freq_55': 10548.08,
#  'freq_56': 11175.3,
#  'freq_57': 11839.82,
#  'freq_58': 12543.85,
#  'freq_59': 13289.75,
#  'freq_60': 14080.0,
#  'freq_61': 14917.24,
#  'freq_62': 15804.27,
#  'freq_63': 16744.04,
#  'freq_64': 17739.69,
#  'freq_65': 18794.55,
#  'freq_66': 19912.13,
#  'freq_67': 21096.16,
#  'freq_68': 22350.61,
#  'freq_69': 23679.64,
#  'freq_70': 25087.71,
#  'freq_71': 26579.5,
#  'freq_72': 28160.0,
#  'freq_73': 29834.48,
#  'freq_74': 31608.53,
#  'freq_75': 33488.07,
#  'freq_76': 35479.38,
#  'freq_77': 37589.09,
#  'freq_78': 39824.25,
#  'freq_79': 42192.33,
#  'freq_80': 44701.21,
#  'freq_81': 47359.29,
#  'freq_82': 50175.42,
#  'freq_83': 53159.0,
#  'freq_84': 56320.0,
#  'freq_85': 59668.96,
#  'freq_86': 63217.06,
#  'freq_87': 66976.14}

# %%
overtone_series = PITCH.make_overtone_series()

# %%
W = generator.Wav(carrier_hz=PITCH.hz)

# %%
W.make_wav('square_duty')

# %%
W.show_wav('square_duty', zoom=300)

# %%
W.__dict__
# Out:
# {'_Wav__hz': 440.0,
#  '_Wav__sr': 44100,
#  '_Wav__duration': 10.0,
#  '_Wav__duty': 0.8,
#  '_Wav__modulator': 6.123233995736766e-16,
#  '_Wav__t_samples': array([0.00000e+00, 1.00000e+00, 2.00000e+00, ..., 4.40997e+05,
#         4.40998e+05, 4.40999e+05]),
#  '_Wav__wav': array([0.00000000e+00, 6.26893772e-02, 1.25378754e-01, ...,
#         2.76458273e+04, 2.76458900e+04, 2.76459527e+04]),
#  '_Wav__W': {'sine': array([ 0.        ,  0.06264832,  0.12505052, ..., -0.18696144,
#          -0.12505052, -0.06264832]),
#   'square': array([ 1.,  1.,  1., ..., -1., -1., -1.]),
#   'square_duty': array([ 1.,  1.,  1., ..., -1., -1., -1.]),
#   'sawtooth': array([-1.        , -0.98004535, -0.9600907 , ...,  0.94013605,
#           0.9600907 ,  0.98004535]),
#   'triangle': array([1.        , 0.98004535, 0.9600907 , ..., 0.94013605, 0.9600907 ,
#          0.98004535])}}

# %%
W.show_wav('square', zoom=300)

# %%
print(overtone_series[3])
DET = util.Detect(start_freq=overtone_series[3])
# Out:
# 1320.0

# %%
DET.closest_pitch()
# Out:
# 'E6'

# %%
DET.find_offset_from_closet_pitch()
# Out:
# ('E6', 1.96)

# %%
overtone_series[3] - DET.find_offset_from_closet_pitch()[1]
# Out:
# 1318.04

# %%
util.Transform.pitch_to_hz['E'][6]
# Out:
# 1318.51
